# %%
import sys
print(sys.executable)
# Out:
# c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Scripts\python.exe

# %%
from qdrant_client import QdrantClient, models
from dotenv import load_dotenv
import os

# %%
client = QdrantClient(url=os.getenv("QDRANT_URL"), api_key=os.getenv("QDRANT_API_KEY"))

# For Colab:
# from google.colab import userdata
# client = QdrantClient(url=userdata.get("QDRANT_URL"), api_key=userdata.get("QDRANT_API_KEY"))

# Quick health check
collections = client.get_collections()
print(f"Connected to Qdrant Cloud: {len(collections.collections)} collections")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\http\api_client.py:134, in ApiClient.send_inner(self, request)
#     133 try:
# --> 134     response = self._client.send(request)
#     135 except Exception as e:
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Cell In[3], line 8
#       1 client = QdrantClient(url=os.getenv("QDRANT_URL"), api_key=os.getenv("QDRANT_API_KEY"))
#       3 # For Colab:
#       4 # from google.colab import userdata
#       5 # client = QdrantClient(url=userdata.get("QDRANT_URL"), api_key=userdata.get("QDRANT_API_KEY"))
#       6
#       7 # Quick health check
# ----> 8 collections = client.get_collections()
#       9 print(f"Connected to Qdrant Cloud: {len(collections.collections)} collections")
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\qdrant_client.py:1521, in QdrantClient.get_collections(self, **kwargs)
#    1514 """Get list name of all existing collections
#    1515
#    1516 Returns:
#    1517     List of the collections
#    1518 """
#    1519 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 1521 return self._client.get_collections(**kwargs)
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\qdrant_remote.py:1786, in QdrantRemote.get_collections(self, **kwargs)
#    1775     response = self.grpc_collections.List(
#    1776         grpc.ListCollectionsRequest(), timeout=self._timeout
#    1777     ).collections
#    1778     return types.CollectionsResponse(
#    1779         collections=[
#    1780             GrpcToRest.convert_collection_description(description)
#    1781             for description in response
#    1782         ]
#    1783     )
#    1785 result: types.CollectionsResponse | None = (
# -> 1786     self.http.collections_api.get_collections().result
#    1787 )
#    1788 assert result is not None, "Get collections returned None"
#    1789 return result
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\http\api\collections_api.py:330, in SyncCollectionsApi.get_collections(self)
#     324 def get_collections(
#     325     self,
#     326 ) -> m.InlineResponse2003:
#     327     """
#     328     Get list name of all existing collections
#     329     """
# --> 330     return self._build_for_get_collections()
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\http\api\collections_api.py:159, in _CollectionsApi._build_for_get_collections(self)
#     155 """
#     156 Get list name of all existing collections
#     157 """
#     158 headers = {}
# --> 159 return self.api_client.request(
#     160     type_=m.InlineResponse2003,
#     161     method="GET",
#     162     url="/collections",
#     163     headers=headers if headers else None,
#     164 )
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\http\api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\http\api_client.py:112, in ApiClient.send(self, request, type_)
#     111 def send(self, request: Request, type_: Type[T]) -> T:
# --> 112     response = self.middleware(request, self.send_inner)
#     114     if response.status_code == 429:
#     115         retry_after_s = response.headers.get("Retry-After", None)
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\http\api_client.py:250, in BaseMiddleware.__call__(self, request, call_next)
#     249 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 250     return call_next(request)
#
# File c:\Users\lzandrade.TOPAZ\AppData\Local\hatch\env\virtual\materials\URYRdbY_\materials\Lib\site-packages\qdrant_client\http\api_client.py:136, in ApiClient.send_inner(self, request)
#     134     response = self._client.send(request)
#     135 except Exception as e:
# --> 136     raise ResponseHandlingException(e)
#     137 return response
#
# ResponseHandlingException: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
